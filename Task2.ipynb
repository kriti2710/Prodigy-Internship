# %% [markdown]
# <a href="https://colab.research.google.com/github/kriti2710/Prodigy-Internship/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv')
test_data=pd.read_csv('test.csv')

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns # Import seaborn and use the conventional alias
import matplotlib.pyplot as plt

# Assuming 'train_data' is your DataFrame
sns.countplot(x='Survived', data=train_data) # Use sns.countplot
plt.show()

# %%
train_data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

train_data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
sns.countplot(x='Sex', hue='Survived', data=train_data) # Make sure 'Sex' and 'Survived' are column names, not DataFrames
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Verify 'Pclass' is a column in 'train_data'
print(train_data.columns)

# If 'Pclass' is a column, use this:
sns.countplot(x='Pclass', hue='Survived', data=train_data)

#If 'Pclass' is a DataFrame, use this:
# sns.countplot(x='RelevantColumnName', hue='Survived', data=Pclass) # Replace 'RelevantColumnName'

plt.title('Pclass: Sruvived vs Dead')
plt.show()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pd.crosstab([train_data.Sex,train_data.Survived],train_data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_89955_row0_col0, #T_89955_row0_col1, #T_89955_row0_col3, #T_89955_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_89955_row0_col2, #T_89955_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_89955_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_89955_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_89955_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_89955_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_89955_row2_col1, #T_89955_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_89955_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_89955_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_89955_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_89955_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Use 'catplot' instead of the deprecated 'factorplot'
sns.catplot(x='Pclass', y='Survived', hue='Sex', kind='bar', data=train_data)
plt.show()

# %%
print('Oldest person Survived was of:',train_data['Age'].max())
print('Youngest person Survived was of:',train_data['Age'].min())
print('Average person Survived was of:',train_data['Age'].mean())
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 29.69911764705882

# %%
import seaborn as sns # Make sure seaborn is imported
import matplotlib.pyplot as plt

f,ax=plt.subplots(1,2,figsize=(18,8))
sns.barplot('Pclass','Age',hue='Survived',data=train_data,split=True,ax=ax[0]) # Use sns instead of sb
ax[0].set_title('PClass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=train_data,split=True,ax=ax[1]) # Use sns instead of sb
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
train_data['Initial']=0
for i in train_data:
    train_data['Initial']=train_data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(train_data.Initial,train_data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_79008_row0_col0, #T_79008_row0_col1, #T_79008_row0_col3, #T_79008_row0_col4, #T_79008_row0_col5, #T_79008_row0_col7, #T_79008_row0_col8, #T_79008_row0_col12, #T_79008_row0_col15, #T_79008_row0_col16, #T_79008_row1_col2, #T_79008_row1_col6, #T_79008_row1_col9, #T_79008_row1_col10, #T_79008_row1_col11, #T_79008_row1_col13, #T_79008_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_79008_row0_col2, #T_79008_row0_col6, #T_79008_row0_col9, #T_79008_row0_col10, #T_79008_row0_col11, #T_79008_row0_col13, #T_79008_row0_col14, #T_79008_row1_col0, #T_79008_row1_col1, #T_79008_row1_col3, #T_79008_row1_col4, #T_79008_row1_col5, #T_79008_row1_col7, #T_79008_row1_col8, #T_79008_row1_col12, #T_79008_row1_col15, #T_79008_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_79008" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
train_data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess',
                               'Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss',
                                'Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Mr'),'Age']=33
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Mrs'),'Age']=36
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Master'),'Age']=5
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Miss'),'Age']=22
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Other'),'Age']=46

# %%
train_data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,20))
train_data[train_data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
train_data[train_data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
ax[1].set_title('Survived = 1')
plt.show()

# %%
pd.crosstab([train_data.SibSp],train_data.Survived).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_64151_row0_col0, #T_64151_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_64151_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_64151_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_64151_row2_col0, #T_64151_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_64151_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_64151_row3_col0, #T_64151_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_64151_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_64151_row5_col0, #T_64151_row5_col1, #T_64151_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_64151_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_64151" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
# ...

# %%
pd.crosstab(train_data.SibSp,train_data.Pclass).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_79bbe_row0_col0, #T_79bbe_row0_col1, #T_79bbe_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_79bbe_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_79bbe_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_79bbe_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_79bbe_row2_col0, #T_79bbe_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_79bbe_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_79bbe_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_79bbe_row3_col0, #T_79bbe_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_79bbe_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_79bbe_row4_col0, #T_79bbe_row4_col1, #T_79bbe_row5_col0, #T_79bbe_row5_col1, #T_79bbe_row5_col2, #T_79bbe_row6_col0, #T_79bbe_row6_col1 {
#   background-color: #ffff66;
# ...
